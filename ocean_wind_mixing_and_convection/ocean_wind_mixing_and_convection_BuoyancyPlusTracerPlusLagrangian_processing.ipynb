# %%
"""
Nonhydrostaticmodel, with buoyancy as tracer(:b) and tracer(:c) and Lagrangian particles all data except halo regions 
10.3.2022
Si Chen

"""
# Out:
# "Nonhydrostaticmodel, with buoyancy as tracer(:b) and tracer(:c) and Lagrangian particles all data except halo regions \n10.3.2022\nSi Chen\n\n"

# %%
using Random
using Printf
using Plots
using JLD2
using Statistics

using Oceananigans
using Oceananigans.Advection
using Oceananigans.Operators
using Oceananigans.Fields: ZeroField
using Oceananigans.Fields: BackgroundFields, Field, tracernames, VelocityFields, TracerFields, PressureFields
using Oceananigans.Units: minute, minutes, hour, hours

# %%
Nx = 32
Ny = 32
Nz = 24          # number of points in the vertical direction
Lx = 64          
Ly = 64          
Lz = 32          # (m) domain depth


"""

refinement = 1.2 # controls spacing near surface (higher means finer spaced)
stretching = 12  # controls rate of stretching at bottom

# Normalized height ranging from 0 to 1
h(k) = (k - 1) / Nz

# Linear near-surface generator
ζ₀(k) = 1 + (h(k) - 1) / refinement

# Bottom-intensified stretching function
Σ(k) = (1 - exp(-stretching * h(k))) / (1 - exp(-stretching))

# Generating function
z_faces(k) = Lz * (ζ₀(k) * Σ(k) - 1)
"""
grid = RectilinearGrid(size = (Nx, Ny, Nz),
                          x = (0, Lx),   #  Nx*Δx
                          y = (0, Ly),   # Ny*Δy
                          z = (-Lz,0))   # z_faces
# Out:
# grid

# %% [markdown]
# plot(grid.Δzᵃᵃᶜ[1:grid.Nz], grid.zᵃᵃᶜ[1:grid.Nz],
#      marker = :circle,
#      ylabel = "Depth (m)",
#      xlabel = "Vertical spacing (m)",
#      legend = nothing)

# %% [markdown]
# ## Lagrangian particles

# %%
n_particles = 100;
x₀ = Lx*rand(n_particles);  #125*rand(n_particles);
y₀ = Ly*rand(n_particles);
z₀ = -Lz*rand(n_particles);  #0*ones(n_particles)

lagrangian_particles = LagrangianParticles(x=x₀, y=y₀, z=z₀, restitution=0)
# Out:
# 100 Lagrangian particles with
# ├── 3 properties: (:x, :y, :z)
# └── 0 tracked fields: ()

# %% [markdown]
# # Boundary conditions
# ### No Particle boundary conditions

# %%
u₁₀ = 0.00001    # m s⁻¹, average wind velocity 10 meters above the ocean
cᴰ = 2.5e-3 # dimensionless drag coefficient
ρₒ = 1026 # kg m⁻³, average density at the surface of the world ocean
ρₐ = 1.225  # kg m⁻³, average density of air at sea-level

Qᵘ = - ρₐ / ρₒ * cᴰ * u₁₀ * abs(u₁₀) # m² s⁻²   kinematic stress: stress divided by density 

u_bcs = FieldBoundaryConditions(top = FluxBoundaryCondition(Qᵘ))
# Out:
# Oceananigans.FieldBoundaryConditions, with boundary conditions
# ├── west: DefaultBoundaryCondition
# ├── east: DefaultBoundaryCondition
# ├── south: DefaultBoundaryCondition
# ├── north: DefaultBoundaryCondition
# ├── bottom: DefaultBoundaryCondition
# ├── top: FluxBoundaryCondition: -2.98489e-16
# └── immersed: FluxBoundaryCondition: Nothing

# %%
B₀ = 4.24e-8    #m²s⁻³  B₀ = -4.24e-8  
N² = 9e-6    #dbdz=N^2, s⁻²
buoyancy_bcs = FieldBoundaryConditions(top = FluxBoundaryCondition(B₀),
                                       bottom = GradientBoundaryCondition(N²))
#https://clima.github.io/OceananigansDocumentation/stable/generated/convecting_plankton/
#=

The flux convention in Oceananigans.jl
Fluxes are defined by the direction a quantity is carried: positive velocities produce positive fluxes, while negative velocities produce negative fluxes. 
Diffusive fluxes are defined with the same convention. 
A positive flux at the top boundary transports buoyancy upwards, out of the domain. 
This means that a positive flux of buoyancy at the top boundary reduces the buoyancy of near-surface fluid, causing convection.

=#
# Out:
# Oceananigans.FieldBoundaryConditions, with boundary conditions
# ├── west: DefaultBoundaryCondition
# ├── east: DefaultBoundaryCondition
# ├── south: DefaultBoundaryCondition
# ├── north: DefaultBoundaryCondition
# ├── bottom: GradientBoundaryCondition: 9.0e-6
# ├── top: FluxBoundaryCondition: 4.24e-8
# └── immersed: FluxBoundaryCondition: Nothing

# %% [markdown]
# ## Forcing
#
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Grids/rectilinear_grid.jl
#
#
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Grids/zeros.jl
#
# div_Uc
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Advection/tracer_advection_operators.jl
#
# δzᵃᵃᶜ
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Operators/difference_operators.jl
#
# advective_tracer_flux_z
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Advection/centered_advective_fluxes.jl
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Advection/centered_second_order.jl

# %%
# Add an extra advection term to the tracer equation to account for a 'slip' velocity

ws = 0.001;   # slip velocity (in m/s)
λ = 1;      # 2 decay length of slip velocity at z=0 (m)，Si:deeper than this, slip velocity is very close to ws.
# create an empty array to store the slip velocity (this is a tuple)
slip_vel = (u=zeros(0:Nx+2,0:Ny+2,0:Nz+2),v=zeros(0:Nx+2,0:Ny+2,0:Nz+2),w=zeros(0:Nx+2,0:Ny+2,0:Nz+2))
# because div_Uc is 3D, so slip_vel has to be defined 3D.
# zeros function in Oceananigans is different in Julia because in Julia zeros(0:2) erros.
# to learn the dimensions and indices see the following  
# when build it has with 1×1×1 halo, after calculation, it has 3×3×3 halo, actuall 3 in both sides of each direction  

# define the non-zero components(s) of the slip velocity
# to conserve mass, the slip velocity should =0 at z=0
# The width of the tanh will depend on the advection scheme and integrated tracer conservation should be checked
for k=0:Nz+2
  #slip_vel.w[:,:,k].+=ws*tanh(max((-grid.zᵃᵃᶠ[k]-5)/λ,0));   # don't need .+=  this "+"
    
    #slip_vel.w[:,:,k].=grid.zᵃᵃᶠ[k] > -Lz/2 ? ws*tanh(max(-grid.zᵃᵃᶠ[k]-depth_zero,0)/λ) : ws*tanh(max(Lz + grid.zᵃᵃᶠ[k] - depth_zero,0)/λ)   
    slip_vel.w[:,:,k].+=ws*(tanh(max(-grid.zᵃᵃᶠ[k]/λ,0))*tanh(max((grid.zᵃᵃᶠ[k]+Lz)/λ,0)));
    
    
    # max means that for those smaller than 0, set to zeros.   
    #ttps://baike.baidu.com/item/%E5%AF%B9%E7%A7%B0%E5%8F%98%E6%8D%A2/4729638
    #y=f(2a－x)  and y=f(x) is symmetric around x=a
end

# define the RHS forcing term for advection by the slip velocity using the inbuilt advection operator
# Different advection schemes can be specified here

slip_advection(i, j, k, grid, clock, model_fields) = - div_Uc(i,j,k,grid,CenteredSecondOrder(),slip_vel,model_fields.c)  

#slip_advection(i, j, k, grid, clock, model_fields) = - div_Uc(i,j,k,grid,WENO5(grid = grid),slip_vel,model_fields.c)  

# @inline div_Uc(i, j, k, grid, ::Nothing, U, c) = zero(eltype(grid)) seems like it's ok without advection argument
#https://github.com/CliMA/Oceananigans.jl/blob/main/src/Advection/tracer_advection_operators.jl


# because div_Uc is 3D, so slip_vel has to be defined 3D. 
# see: /src/Advection/centered_second_order.jl here it also defined a constant: const C2 = CenteredSecondOrder L14
# try different scheme like WENO5 https://github.com/CliMA/Oceananigans.jl/blob/main/src/Advection/weno_fifth_order.jl

slip_forcing = Forcing(slip_advection, discrete_form=true)

#see: https://clima.github.io/OceananigansDocumentation/stable/model_setup/forcing_functions/
    # 1 Forcing functions with external parameters means only influencing x,y,z,t
    # 2 Forcing functions that depend on model fields means may influence u,v,w,S,T, etc.  
    # 3 "Discrete form" forcing functions means by using model_fields argument, it can access all the model field data u,v,w, 
         # and all tracers through like model_fields.b, model_fields.u, model_fields.c  , etc. 
    # "Discrete form" forcing functions
# Out:
# DiscreteForcing{Nothing}
# ├── func: slip_advection (generic function with 1 method)
# └── parameters: nothing

# %%
plot(slip_vel.w[1,1,1:Nz+1],grid.zᵃᵃᶠ[1:Nz+1],        #1:Nz+1
    marker = :circle,
    ylabel = "Depth (m)",
    xlabel = "Slip Velocities (ms⁻¹)",
    legend=:topleft)

# %% [markdown]
# # Model instantiation

# %%
model = NonhydrostaticModel(
                            advection = UpwindBiasedFifthOrder(),
                            timestepper = :RungeKutta3,
                            grid = grid,
                            tracers = (:b,:c),                        
                            coriolis = FPlane(f=1e-4),
                            buoyancy = BuoyancyTracer(),
                            particles = lagrangian_particles,
                            closure = AnisotropicMinimumDissipation(),
                            forcing = (c=slip_forcing,),
                            #boundary_conditions = (b=buoyancy_bcs,))
                            boundary_conditions = (u=u_bcs, b=buoyancy_bcs))  # the order shouldnt be changed
# Out:
# ┌ Warning: Inflating model grid halo size to (3, 3, 3) and recreating grid. The model grid will be different from the input grid. To avoid this warning, pass halo=(3, 3, 3) when constructing the grid.
# └ @ Oceananigans.Models.NonhydrostaticModels /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Models/NonhydrostaticModels/nonhydrostatic_model.jl:147
# NonhydrostaticModel{CPU, RectilinearGrid}(time = 0 seconds, iteration = 0)
# ├── grid: 32×32×24 RectilinearGrid{Float64, Periodic, Periodic, Bounded} on CPU with 3×3×3 halo
# ├── timestepper: RungeKutta3TimeStepper
# ├── tracers: (b, c)
# ├── closure: AnisotropicMinimumDissipation{Oceananigans.TurbulenceClosures.ExplicitTimeDiscretization, NamedTuple{(:b, :c), Tuple{Float64, Float64}}, Float64, Nothing}
# ├── buoyancy: BuoyancyTracer with -ĝ = ZDirection
# ├── coriolis: FPlane{Float64}(f=0.0001)
# └── particles: 100 Lagrangian particles with 3 properties: (:x, :y, :z)

# %% [markdown]
# # Initial conditions
#
# https://juliacn.gitlab.io/JuliaZH.jl/manual/functions.html
#
# https://clima.github.io/OceananigansDocumentation/stable/generated/convecting_plankton/

# %%
# Random noise damped at top and bottom
Ξ(z) = randn() * z / model.grid.Lz * (1 + z / model.grid.Lz) # noise

# Velocity initial condition: random noise scaled by the friction velocity.
uᵢ(x, y, z) = sqrt(abs(Qᵘ)) * 1e-3 * Ξ(z)

cᵢ(x, y, z) = exp(z/10)

mixed_layer_depth = -20  # m
∂b∂z(z) = z > mixed_layer_depth ? 0 : N²   # https://juliacn.gitlab.io/JuliaZH.jl/manual/functions.html

b₀(x, y, z) = ∂b∂z(z) * z 
#https://clima.github.io/OceananigansDocumentation/stable/generated/convecting_plankton/

set!(model, u=uᵢ, w=uᵢ, b=b₀, c=cᵢ)
#set!(model, b=b₀, c=cᵢ)

# %% [markdown]
# # Setting up a simulation
#
# https://github.com/CliMA/Oceananigans.jl/blob/main/src/Simulations/time_step_wizard.jl
#
# https://github.com/CliMA/Oceananigans.jl/blob/fdddf1a0d2e3434ef9f05c6ae2d64d0edabceb38/src/Simulations/simulation.jl#L111-L115

# %%
#simulation = Simulation(model, Δt=10.0, stop_time=60minutes)  # Simulation(model, Δt=10.0, stop_time=60minutes)

simulation = Simulation(model, Δt=2minutes, stop_time=4hours)

wizard = TimeStepWizard(cfl=1.0, max_change=1.1, max_Δt=2minute)

simulation.callbacks[:wizard] = Callback(wizard, IterationInterval(10))


"""
julia> simulation = Simulation(model, Δt=0.9, stop_iteration=100)
julia> wizard = TimeStepWizard(cfl=0.2)
julia> simulation.callbacks[:wizard] = Callback(wizard, IterationInterval(4))

Then when `run!(simulation)` is invoked, the time-step `simulation.Δt` will be updated every 4 iterations.
Note that the name `:wizard` is unimportant.
"""
# Out:
# "julia> simulation = Simulation(model, Δt=0.9, stop_iteration=100)\njulia> wizard = TimeStepWizard(cfl=0.2)\njulia> simulation.callbacks[:wizard] = Callback(wizard, IterationInterval(4))\n\nThen when `run!(simulation)` is invoked, the time-step `simulation.Δt` will be updated every 4 iterations.\nNote that the name `:wizard` is unimportant.\n"

# %%
# Print a progress message
progress_message(sim) = @printf("Iteration: %04d, time: %s, Δt: %s, max(|w|) = %.1e ms⁻¹, wall time: %s\n",
                                iteration(sim),
#src/Simulations/simulation.jl#L111-L115
                                prettytime(sim),
                                prettytime(sim.Δt),
                                maximum(abs, sim.model.velocities.w),
                                prettytime(sim.run_wall_time))
#prettytime: Convert a floating point value to a more human-friendly formatted string with three decimal places.
# also a generic function 
simulation.callbacks[:progress] = Callback(progress_message, IterationInterval(10))
# Out:
# Callback of progress_message on IterationInterval(10)

# %% [markdown]
# # output
#
# https://docs.juliahub.com/Oceananigans/hU93i/0.45.2/library/#Oceananigans.OutputWriters.JLD2OutputWriter
#  https://github.com/CliMA/Oceananigans.jl/blob/fdddf1a0d2e3434ef9f05c6ae2d64d0edabceb38/src/OutputWriters/jld2_output_writer.jl

# %%
# Create a NamedTuple with eddy viscosity
eddy_viscosity = (; νₑ = model.diffusivity_fields.νₑ)

simulation.output_writers[:slices] =
    JLD2OutputWriter(model, merge(model.velocities, model.tracers, eddy_viscosity),
                           prefix = "ocean_wind_mixing_and_convection_BuoyancyPlusTracerPlusLagrangian",
                     #field_slicer = FieldSlicer(j=Int(grid.Ny/2)), #here save only along y direction
                        #field_slicer = FieldSlicer(),   #include all data except halo retions
                          indices = (:, :, :), 
                        with_halos = false,
    
# field_slicer = nothing` means no slicing occurs, so that all field data, including halo regions, is saved.
#Default: FieldSlicer(), which slices halo regions. 
#FieldSlicer() Si: only grid includes halos,+-3,and u,v,w, and all field data don't include halo. 
#don't forget z include lower bound but face and center have different dimensions.
                         schedule = TimeInterval(1minute),
                            force = true)

simulation.output_writers[:particles] = JLD2OutputWriter(model, (particles=model.particles,), 
                               prefix = "particles",
                             schedule = TimeInterval(1minute),
                               force = true)
# Out:
# JLD2OutputWriter scheduled on TimeInterval(1 minute):
# ├── filepath: ./particles.jld2
# ├── 1 outputs: particles
# ├── array type: Array{Float32}
# ├── including: [:grid, :coriolis, :buoyancy, :closure]
# └── max filesize: Inf YiB

# %%
run!(simulation)   # Δt is changing.
# Out:
# Iteration: 0000, time: 0 seconds, Δt: 2 minutes, max(|w|) = 1.1e-11 ms⁻¹, wall time: 0 seconds
# Iteration: 0010, time: 10 minutes, Δt: 2 minutes, max(|w|) = 2.8e-11 ms⁻¹, wall time: 5.064 seconds
# Iteration: 0020, time: 20 minutes, Δt: 2 minutes, max(|w|) = 3.0e-10 ms⁻¹, wall time: 7.263 seconds
# Iteration: 0030, time: 30 minutes, Δt: 2 minutes, max(|w|) = 3.5e-09 ms⁻¹, wall time: 9.496 seconds
# Iteration: 0040, time: 40 minutes, Δt: 2 minutes, max(|w|) = 4.0e-08 ms⁻¹, wall time: 11.738 seconds
# Iteration: 0050, time: 50 minutes, Δt: 2 minutes, max(|w|) = 4.5e-07 ms⁻¹, wall time: 13.904 seconds
# Iteration: 0060, time: 1 hour, Δt: 2 minutes, max(|w|) = 5.2e-06 ms⁻¹, wall time: 16.101 seconds
# Iteration: 0070, time: 1.167 hours, Δt: 2 minutes, max(|w|) = 5.9e-05 ms⁻¹, wall time: 18.338 seconds
# Iteration: 0080, time: 1.333 hours, Δt: 2 minutes, max(|w|) = 6.1e-04 ms⁻¹, wall time: 20.546 seconds
# Iteration: 0090, time: 1.500 hours, Δt: 2 minutes, max(|w|) = 4.5e-03 ms⁻¹, wall time: 22.745 seconds
# Iteration: 0100, time: 1.667 hours, Δt: 1.032 minutes, max(|w|) = 2.2e-02 ms⁻¹, wall time: 25.072 seconds
# Iteration: 0110, time: 1.833 hours, Δt: 1.135 minutes, max(|w|) = 1.9e-02 ms⁻¹, wall time: 27.312 seconds
# Iteration: 0120, time: 2 hours, Δt: 50.756 seconds, max(|w|) = 2.6e-02 ms⁻¹, wall time: 29.508 seconds
# Iteration: 0130, time: 2.083 hours, Δt: 46.966 seconds, max(|w|) = 2.8e-02 ms⁻¹, wall time: 31.551 seconds
# Iteration: 0140, time: 2.167 hours, Δt: 45.489 seconds, max(|w|) = 2.9e-02 ms⁻¹, wall time: 33.624 seconds
# Iteration: 0150, time: 2.250 hours, Δt: 47.353 seconds, max(|w|) = 2.8e-02 ms⁻¹, wall time: 35.668 seconds
# Iteration: 0160, time: 2.333 hours, Δt: 49.441 seconds, max(|w|) = 2.7e-02 ms⁻¹, wall time: 37.742 seconds
# Iteration: 0170, time: 2.417 hours, Δt: 54.061 seconds, max(|w|) = 2.5e-02 ms⁻¹, wall time: 39.790 seconds
# Iteration: 0180, time: 2.500 hours, Δt: 59.278 seconds, max(|w|) = 2.2e-02 ms⁻¹, wall time: 41.826 seconds
# Iteration: 0190, time: 2.583 hours, Δt: 1.015 minutes, max(|w|) = 2.2e-02 ms⁻¹, wall time: 43.875 seconds
# Iteration: 0200, time: 2.750 hours, Δt: 1.031 minutes, max(|w|) = 2.2e-02 ms⁻¹, wall time: 46.124 seconds
# Iteration: 0210, time: 2.917 hours, Δt: 1.135 minutes, max(|w|) = 1.8e-02 ms⁻¹, wall time: 48.304 seconds
# Iteration: 0220, time: 3.083 hours, Δt: 1.248 minutes, max(|w|) = 1.6e-02 ms⁻¹, wall time: 50.498 seconds
# Iteration: 0230, time: 3.250 hours, Δt: 1.003 minutes, max(|w|) = 2.2e-02 ms⁻¹, wall time: 52.748 seconds
# Iteration: 0240, time: 3.417 hours, Δt: 1.104 minutes, max(|w|) = 1.9e-02 ms⁻¹, wall time: 54.931 seconds
# Iteration: 0250, time: 3.583 hours, Δt: 1.046 minutes, max(|w|) = 2.1e-02 ms⁻¹, wall time: 57.118 seconds
# Iteration: 0260, time: 3.750 hours, Δt: 1.063 minutes, max(|w|) = 2.1e-02 ms⁻¹, wall time: 59.352 seconds
# Iteration: 0270, time: 3.917 hours, Δt: 1.013 minutes, max(|w|) = 2.2e-02 ms⁻¹, wall time: 1.028 minutes
# ┌ Info: Initializing simulation...
# └ @ Oceananigans.Simulations /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Simulations/run.jl:167
# ┌ Info:     ... simulation initialization complete (151.385 ms)
# └ @ Oceananigans.Simulations /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Simulations/run.jl:202
# ┌ Info: Executing initial time step...
# └ @ Oceananigans.Simulations /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Simulations/run.jl:112
# ┌ Info:     ... initial time step complete (3.081 seconds).
# └ @ Oceananigans.Simulations /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Simulations/run.jl:119
# ┌ Info: Simulation is stopping. Model time 4 hours has hit or exceeded simulation stop time 4 hours.
# └ @ Oceananigans.Simulations /home/sichen/.julia/packages/Oceananigans/JIHfS/src/Simulations/simulation.jl:165

# %% [markdown]
# ## Visualization

# %%
""" Returns colorbar levels equispaced between `(-clim, clim)` and encompassing the extrema of `c`. """
function divergent_levels(c, clim, nlevels=21) 
    # the input clim is only one number,divergent_levels is for those the output is 
    # symmetric(on positive and negative sides), like velocity
    cmax = maximum(abs, c)  
    #Compute the maximum value by calling the function abs on each element of c over the given dimensions.
    # i.e. calculate abs first than max
    levels = clim > cmax ? range(-clim, stop=clim, length=nlevels) : range(-cmax, stop=cmax, length=nlevels)
    return (levels[1], levels[end]), levels
end

""" Returns colorbar levels equispaced between `clims` and encompassing the extrema of `c`."""
function sequential_levels(c, clims, nlevels=20)
        # the input clims is a range, sequential_levels is for those the output is 
        # nonsymmetric(on positive and negative sides), like scalars 
    levels = range(clims[1], stop=clims[2], length=nlevels)
    cmin, cmax = minimum(c), maximum(c)
    cmin < clims[1] && (levels = vcat([cmin], levels)) 
    cmax > clims[2] && (levels = vcat(levels, [cmax]))
    return (levels[1], levels[end]), levels    # I think the return should like this
    #return clims, levels
end
# Out:
# sequential_levels

# %%
# Coordinate arrays
xw, yw, zw = nodes(model.velocities.w)  #there is no real practical data in “model”, just the structure
xb, yb, zb = nodes(model.tracers.b)   # velocity field is located on Face while scalar is located on Center

# Open the file with our data
file = jldopen(simulation.output_writers[:slices].filepath)

# Extract a vector of iterations
iterations = parse.(Int, keys(file["timeseries/t"])) # turn an array of strings into numbers 

times = [file["timeseries/t/$iter"] for iter in iterations]
intro = searchsortedfirst(times, 10minutes);  
# show results from 10 minutes 
# https://cn.julialang.org/JuliaZH.jl/latest/base/sort/#Base.Sort.searchsortedfirst
keys(file)
# Out:
# 5-element Vector{String}:
#  "grid"
#  "coriolis"
#  "closure"
#  "serialized"
#  "timeseries"

# %%
anim = @animate for (i, iter) in enumerate(iterations[intro:end])

    @info "Drawing frame $i from iteration $iter..."

    t = file["timeseries/t/$iter"]
    w = file["timeseries/w/$iter"][:, 1, :]
    b = file["timeseries/b/$iter"][:, 1, :]
    c = file["timeseries/c/$iter"][:, 1, :]
    #S = file["timeseries/S/$iter"][:, 1, :]
    νₑ = file["timeseries/νₑ/$iter"][:, 1, :]

    wlims, wlevels = divergent_levels(w, 2e-2)              #functions defined above
    blims, blevels = sequential_levels(b, (-3e-4, 5e-5))   # (-3e-4, 5e-5)
    clims, clevels = sequential_levels(c, (0, 1))
    #Slims, Slevels = sequential_levels(S, (35, 35.005))
    νlims, νlevels = sequential_levels(νₑ, (1e-6, 5e-3))

    kwargs = (linewidth=0, xlabel="x (m)", ylabel="z (m)", aspectratio=1,
              xlims=(0, grid.Lx), ylims=(-grid.Lz, 0))

    w_plot = contourf(xw, zw, w'; color=:balance, clims=wlims, levels=wlevels, kwargs...)
    b_plot = contourf(xb, zb, b'; color=:thermal, clims=blims, levels=blevels, kwargs...)
    c_plot = contourf(xb, zb, c'; color=:thermal, clims=clims, levels=clevels, kwargs...)
    # argument clims:  Fixes the limits of the colorbar.
        #https://docs.juliaplots.org/latest/generated/attributes_subplot/
    # argument levels: Determines contour levels for a contour type.
        #https://docs.juliaplots.org/latest/generated/attributes_series/ 
    
    #S_plot = contourf(xT, zT, S'; color=:haline,  clims=Slims, levels=Slevels, kwargs...)

    # We use a heatmap for the eddy viscosity to observe how it varies on the grid scale.
    ν_plot = heatmap(xb, zb, νₑ'; color=:thermal, clims=νlims, levels=νlevels, kwargs...)

    w_title = @sprintf("vertical velocity (ms⁻¹), t = %s", prettytime(t))
    b_title = "buoyancy (ms⁻²)"
    c_title = "tracer"
    #S_title = "salinity (g kg⁻¹)"
    ν_title = "eddy viscosity (m²s⁻¹)"

    # Arrange the plots side-by-side.
    plot(w_plot, b_plot, c_plot, ν_plot, layout=(2, 2), size=(1200, 600),
         title=[w_title b_title c_title ν_title])

    #iter == iterations[end] && close(file) # keep file open until all process is done
end
# Out:
# ┌ Info: Drawing frame 1 from iteration 10...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 2 from iteration 11...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 3 from iteration 12...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 4 from iteration 13...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 5 from iteration 14...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 6 from iteration 15...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 7 from iteration 16...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 8 from iteration 17...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 9 from iteration 18...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 10 from iteration 19...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 11 from iteration 20...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 12 from iteration 21...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 13 from iteration 22...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 14 from iteration 23...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 15 from iteration 24...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 16 from iteration 25...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 17 from iteration 26...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 18 from iteration 27...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 19 from iteration 28...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 20 from iteration 29...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 21 from iteration 30...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 22 from iteration 31...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 23 from iteration 32...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 24 from iteration 33...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 25 from iteration 34...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 26 from iteration 35...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 27 from iteration 36...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 28 from iteration 37...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 29 from iteration 38...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 30 from iteration 39...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 31 from iteration 40...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 32 from iteration 41...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 33 from iteration 42...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 34 from iteration 43...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 35 from iteration 44...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 36 from iteration 45...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 37 from iteration 46...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 38 from iteration 47...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 39 from iteration 48...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 40 from iteration 49...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 41 from iteration 50...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 42 from iteration 51...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 43 from iteration 52...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 44 from iteration 53...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 45 from iteration 54...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 46 from iteration 55...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 47 from iteration 56...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 48 from iteration 57...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 49 from iteration 58...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 50 from iteration 59...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 51 from iteration 60...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 52 from iteration 61...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 53 from iteration 62...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 54 from iteration 63...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 55 from iteration 64...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 56 from iteration 65...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 57 from iteration 66...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 58 from iteration 67...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 59 from iteration 68...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 60 from iteration 69...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 61 from iteration 70...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 62 from iteration 71...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 63 from iteration 72...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 64 from iteration 73...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 65 from iteration 74...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 66 from iteration 75...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 67 from iteration 76...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 68 from iteration 77...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 69 from iteration 78...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 70 from iteration 79...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 71 from iteration 80...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 72 from iteration 81...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 73 from iteration 82...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 74 from iteration 83...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 75 from iteration 84...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 76 from iteration 85...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 77 from iteration 86...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 78 from iteration 87...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 79 from iteration 88...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 80 from iteration 89...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 81 from iteration 90...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 82 from iteration 91...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 83 from iteration 92...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 84 from iteration 93...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 85 from iteration 94...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 86 from iteration 95...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 87 from iteration 96...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 88 from iteration 97...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 89 from iteration 98...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 90 from iteration 99...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 91 from iteration 100...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 92 from iteration 101...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 93 from iteration 102...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 94 from iteration 103...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 95 from iteration 104...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 96 from iteration 105...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 97 from iteration 106...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 98 from iteration 107...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 99 from iteration 108...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 100 from iteration 109...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 101 from iteration 110...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 102 from iteration 111...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 103 from iteration 112...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 104 from iteration 113...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 105 from iteration 114...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 106 from iteration 115...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 107 from iteration 116...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 108 from iteration 117...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 109 from iteration 118...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 110 from iteration 119...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 111 from iteration 120...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 112 from iteration 122...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 113 from iteration 124...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 114 from iteration 126...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 115 from iteration 128...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 116 from iteration 130...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 117 from iteration 132...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 118 from iteration 134...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 119 from iteration 136...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 120 from iteration 138...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 121 from iteration 140...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 122 from iteration 142...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 123 from iteration 144...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 124 from iteration 146...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 125 from iteration 148...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 126 from iteration 150...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 127 from iteration 152...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 128 from iteration 154...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 129 from iteration 156...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 130 from iteration 158...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 131 from iteration 160...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 132 from iteration 162...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 133 from iteration 164...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 134 from iteration 166...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 135 from iteration 168...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 136 from iteration 170...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 137 from iteration 172...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 138 from iteration 174...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 139 from iteration 176...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 140 from iteration 178...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 141 from iteration 180...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 142 from iteration 182...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 143 from iteration 184...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 144 from iteration 186...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 145 from iteration 188...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 146 from iteration 190...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 147 from iteration 191...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 148 from iteration 192...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 149 from iteration 193...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 150 from iteration 194...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 151 from iteration 195...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 152 from iteration 196...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 153 from iteration 197...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 154 from iteration 198...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 155 from iteration 199...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 156 from iteration 200...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 157 from iteration 201...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 158 from iteration 202...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 159 from iteration 203...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 160 from iteration 204...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 161 from iteration 205...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 162 from iteration 206...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 163 from iteration 207...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 164 from iteration 208...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 165 from iteration 209...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 166 from iteration 210...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 167 from iteration 211...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 168 from iteration 212...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 169 from iteration 213...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 170 from iteration 214...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 171 from iteration 215...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 172 from iteration 216...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 173 from iteration 217...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 174 from iteration 218...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 175 from iteration 219...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 176 from iteration 220...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 177 from iteration 221...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 178 from iteration 222...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 179 from iteration 223...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 180 from iteration 224...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 181 from iteration 225...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 182 from iteration 226...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 183 from iteration 227...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 184 from iteration 228...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 185 from iteration 229...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 186 from iteration 230...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 187 from iteration 231...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 188 from iteration 232...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 189 from iteration 233...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 190 from iteration 234...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 191 from iteration 235...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 192 from iteration 236...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 193 from iteration 237...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 194 from iteration 238...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 195 from iteration 239...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 196 from iteration 240...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 197 from iteration 241...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 198 from iteration 242...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 199 from iteration 243...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 200 from iteration 244...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 201 from iteration 245...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 202 from iteration 246...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 203 from iteration 247...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 204 from iteration 248...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 205 from iteration 249...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 206 from iteration 250...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 207 from iteration 251...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 208 from iteration 252...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 209 from iteration 253...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 210 from iteration 254...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 211 from iteration 255...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 212 from iteration 256...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 213 from iteration 257...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 214 from iteration 258...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 215 from iteration 259...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 216 from iteration 260...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 217 from iteration 261...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 218 from iteration 262...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 219 from iteration 263...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 220 from iteration 264...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 221 from iteration 265...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 222 from iteration 266...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 223 from iteration 267...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 224 from iteration 268...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 225 from iteration 269...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 226 from iteration 270...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 227 from iteration 271...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 228 from iteration 272...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 229 from iteration 273...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 230 from iteration 274...
# └ @ Main In[136]:3
# ┌ Info: Drawing frame 231 from iteration 275...
# └ @ Main In[136]:3
# Animation("/tmp/jl_74nv5X", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000222.png", "000223.png", "000224.png", "000225.png", "000226.png", "000227.png", "000228.png", "000229.png", "000230.png", "000231.png"])

# %%
gif(anim, "ocean_wind_mixing_and_convection_BuoyancyPlusTracerPlusLagrangian.mp4", fps = 5)  # https://docs.juliaplots.org/latest/animations/
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/ocean_wind_mixing_and_convection_BuoyancyPlusTracerPlusLagrangian.mp4
# └ @ Plots /home/sichen/.julia/packages/Plots/4oFWe/src/animation.jl:114
# Plots.AnimatedGif("/home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/ocean_wind_mixing_and_convection_BuoyancyPlusTracerPlusLagrangian.mp4")

# %% [markdown]
# ## Volume-integrated concentration

# %%
#file = jldopen(simulation.output_writers[:slices].filepath)
#iterations = parse.(Int, keys(file["timeseries/t"]));
#times = [file["timeseries/t/$iter"] for iter in iterations]
#intro = searchsortedfirst(times, 10minutes) # show results from 10 minutes 

# https://cn.julialang.org/JuliaZH.jl/latest/base/sort/#Base.Sort.searchsortedfirst
v_cell=zeros(1,Nz)          #cell volume 

for i in 1:Nz
    #v_cell[i]=grid.Δxᶜᵃᵃ * grid.Δyᵃᶜᵃ * grid.Δzᵃᵃᶜ[i]  # calculate cell volume 1*Nz dimension
    v_cell[i]=grid.Δxᶜᵃᵃ * grid.Δyᵃᶜᵃ * grid.Δzᵃᵃᶜ
end


t=zeros(1,length(iterations)-intro+1)
c=zeros(1,length(iterations)-intro+1)

for (i, iter) in enumerate(iterations[intro:end])
    #println((i,iter))
    t[i] = file["timeseries/t/$iter"]        
    concentration=zeros(Ny,Nz)
    for j in 1:Nx
        concentration+=file["timeseries/c/$iter"][j,:,:].*v_cell
        #add volume-integrated concentration in x plane first
    end
    c[i] = sum(concentration)  # to obtain volume-integrated concentration in whole 3D domain in one timestep

end


plot(t[:]/60,c[:],
     ylims=[35000,40000],   
     marker = :circle,
     legend=:bottomright,
     ylabel = "Volume-integrated concentration",
     xlabel = "Time (minutes)",
     #label = @printf("Max: %.5d, Min: %d, δ: %.6e ", maximum(c),minimum(c),(maximum(c)-minimum(c))/minimum(c) ))
     label = " Max=$(maximum(c)) \n Min=$(minimum(c)) \n δ=$((maximum(c)-minimum(c))/minimum(c)) ")

# %%
v_cell
# Out:
# 1×24 Matrix{Float64}:
#  5.33333  5.33333  5.33333  5.33333  …  5.33333  5.33333  5.33333  5.33333

# %% [markdown]
# ## u_rms, v_rms, w_rms

# %%
concentration=zeros(Nz,length(iterations[intro:end]));

anim2 = @animate for (i, iter) in enumerate(iterations[intro:end])

    #@info "Drawing frame $i from iteration $iter..."

    t = file["timeseries/t/$iter"]
    u_end=file["timeseries/u/$iter"]
    v_end=file["timeseries/v/$iter"]
    w_end=file["timeseries/w/$iter"]
    c_end=file["timeseries/c/$iter"]
    
    u_avg=mean(u_end,dims=(1,2))
    v_avg=mean(v_end,dims=(1,2))
    w_avg=mean(w_end,dims=(1,2))
    c_avg=mean(c_end,dims=(1,2))
    
    u_prime=zeros(Nx,Ny,Nz)
    v_prime=zeros(Nx,Ny,Nz)
    w_prime=zeros(Nx,Ny,Nz)  #its dimension is actually Nx Ny Nz+1
    
    for k in 1:Nz
        u_prime[:,:,k]=u_end[:,:,k].-u_avg[k]  #broadcast array.-scalar 
        v_prime[:,:,k]=v_end[:,:,k].-v_avg[k]
        w_prime[:,:,k]=w_end[:,:,k].-w_avg[k]
    end
    u_rms=(mean((u_end-u_prime).^2,dims=(1,2))).^0.5
    v_rms=(mean((v_end-v_prime).^2,dims=(1,2))).^0.5
    w_rms=(mean((w_end[:,:,1:Nz]-v_prime).^2,dims=(1,2))).^0.5;
    
    #=
    plot(u_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "uᵣₘₛ",
        ylabel = "Depth (m)",
        xlabel = "Velocities (ms⁻¹)",
        xlims = (0,0.3),
        title = @sprintf("RMS velocities (ms⁻¹), t = %s", prettytime(t)))    
    plot!(v_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "vᵣₘₛ")
    plot!(w_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "wᵣₘₛ")
    =#
    
    RMS=plot(u_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "uᵣₘₛ",
        ylabel = "Depth (m)",
        xlabel = "Velocities (ms⁻¹)",
        xlims = (0,0.3),
        title = @sprintf("RMS velocities (ms⁻¹), t = %s", prettytime(t)))    
    RMS = plot!(v_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "vᵣₘₛ")
    RMS = plot!(w_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "wᵣₘₛ")
    concen=plot(c_avg[:],model.grid.zᵃᵃᶜ[1:Nz],
        label = "concentration",
        ylabel = "Depth (m)",
        xlabel = "Mean concentration",
        xlims=(0,1))
    plot(RMS, concen, layout=(1, 2), size=(900, 500),legend=:bottomright)
    concentration[:,i]=c_avg[1,1,:]
    
end


#=

  Average(field; dims=:)

  Return Reduction representing a spatial average of field over dims.

  Over regularly-spaced dimensions this is equivalent to a numerical mean!.

  Over dimensions of variable spacing, field is multipled by the appropriate grid length, area
  or volume, and divided by the total spatial extent of the interval.

=#
# Out:
# Animation("/tmp/jl_epQf3K", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000222.png", "000223.png", "000224.png", "000225.png", "000226.png", "000227.png", "000228.png", "000229.png", "000230.png", "000231.png"])

# %%
gif(anim2, "rms_velocity.mp4", fps = 8)  # https://docs.juliaplots.org/latest/animations/
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/rms_velocity.mp4
# └ @ Plots /home/sichen/.julia/packages/Plots/4oFWe/src/animation.jl:114
# Plots.AnimatedGif("/home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/rms_velocity.mp4")

# %%
u_end=file["timeseries/u/$(iterations[end])"]
v_end=file["timeseries/v/$(iterations[end])"]
w_end=file["timeseries/w/$(iterations[end])"]

u_avg=mean(u_end,dims=(1,2));
v_avg=mean(v_end,dims=(1,2));
w_avg=mean(w_end,dims=(1,2));

u_prime=zeros(Nx,Ny,Nz)
v_prime=zeros(Nx,Ny,Nz)
w_prime=zeros(Nx,Ny,Nz)  #its dimension is actually Nx Ny Nz+1
for k in 1:Nz
    u_prime[:,:,k]=u_end[:,:,k].-u_avg[k]  #broadcast array.-scalar 
    v_prime[:,:,k]=v_end[:,:,k].-v_avg[k]
    w_prime[:,:,k]=w_end[:,:,k].-w_avg[k]
end

u_rms=(mean((u_end-u_prime).^2,dims=(1,2))).^0.5
v_rms=(mean((v_end-v_prime).^2,dims=(1,2))).^0.5
w_rms=(mean((w_end[:,:,1:Nz]-v_prime).^2,dims=(1,2))).^0.5;

plot(u_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "uᵣₘₛ",
     ylabel = "Deepth (m)",
     xlabel = "Velocities (ms⁻¹)")
plot!(v_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "vᵣₘₛ")
plot!(w_rms[:],model.grid.zᵃᵃᶠ[1:Nz],label = "wᵣₘₛ")

#close(file)

# %%
file_particles = jldopen(simulation.output_writers[:particles].filepath)
# Out:
# JLDFile /home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/particles.jld2 (read-only)
#  ├─📂 grid
#  │  ├─🔢 Nx
#  │  ├─🔢 Ny
#  │  ├─🔢 Nz
#  │  ├─🔢 Hx
#  │  ├─🔢 Hy
#  │  ├─🔢 Hz
#  │  ├─🔢 Lx
#  │  └─ ⋯ (14 more entries)
#  └─ ⋯ (4 more entries)

# %%
keys(file_particles)
# Out:
# 5-element Vector{String}:
#  "grid"
#  "coriolis"
#  "closure"
#  "serialized"
#  "timeseries"

# %%
t_p=file_particles["timeseries/t/2"]
# Out:
# 120.0

# %%
p0=file_particles["timeseries/particles/0"]
# Out:
# (x = Float32[3.899921, 29.138186, 39.903893, 22.117033, 37.96351, 38.365616, 46.95165, 57.39458, 22.908205, 17.269808  …  4.4276624, 63.41438, 16.861708, 54.595577, 62.85562, 35.530956, 56.877296, 23.096666, 49.373775, 20.809557], y = Float32[10.649675, 15.839875, 1.5602398, 56.375584, 40.363445, 47.685215, 16.848629, 36.008423, 14.524878, 43.738182  …  11.620604, 63.965008, 16.41908, 46.668964, 44.694622, 15.967518, 44.757183, 14.612541, 32.604763, 1.4687109], z = Float32[-0.21881527, -12.142, -11.837041, -13.35367, -26.574148, -19.676826, -3.7216594, -31.083117, -27.421982, -16.732872  …  -23.396824, -30.916822, -16.207197, -3.285093, -26.62096, -14.600631, -18.537376, -3.0817838, -15.192976, -26.342558])

# %%
scatter(p.x, p.y, p.z,
    color = :blue, 
    markersize=1, 
    legend = false,
    title = @sprintf("Trajectories, t = %s", prettytime(t_p)))

# %%
anim3 = @animate for (i, iter) in enumerate(iterations[intro:end])

    #@info "Drawing frame $i from iteration $iter..."
    t_p=file_particles["timeseries/t/$iter"]
    p=file_particles["timeseries/particles/$iter"]
    scatter!(p.x, p.y, p.z, 
        color = :blue, 
        markersize=1, 
        legend = false,
        title = @sprintf("Trajectories, t = %s", prettytime(t_p)))

end
# Out:
# Animation("/tmp/jl_cBlGFd", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000222.png", "000223.png", "000224.png", "000225.png", "000226.png", "000227.png", "000228.png", "000229.png", "000230.png", "000231.png"])

# %%
gif(anim3, "trajectories.mp4", fps = 8)  # https://docs.juliaplots.org/latest/animations/
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/trajectories.mp4
# └ @ Plots /home/sichen/.julia/packages/Plots/4oFWe/src/animation.jl:114
# Plots.AnimatedGif("/home/sichen/code/my_ocean_model/ocean_wind_mixing_and_convection/trajectories.mp4")
